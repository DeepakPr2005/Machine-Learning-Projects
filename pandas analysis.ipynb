# %% [markdown]
# # 8 Describe about the url port no.

# %%
import pandas as pd
url = "https://stats.espncricinfo.com/ci/content/records/282827.html"
df5 = pd.read_html(url)
a = df5[0]
a = a.head(50)
a
# Out:
#                          Player       Span  Mat  Inns  NO  Runs    HS    Ave  \
# 0                 V Kohli (IND)  2010-2022  115   107  31  4008  122*  52.73
# 1               RG Sharma (IND)  2007-2022  148   140  17  3853   118  31.32
# 2               MJ Guptill (NZ)  2009-2022  122   118   7  3531   105  31.81
# 3              Babar Azam (PAK)  2016-2023  104    98  14  3485   122  41.48
# 4             PR Stirling (IRE)  2009-2023  131   130  11  3408  115*  28.63
# 5                AJ Finch (AUS)  2011-2022  103   103  12  3120   172  34.28
# 6               DA Warner (AUS)  2009-2022   99    99  11  2894  100*  32.88
# 7         Mohammad Rizwan (PAK)  2015-2023   85    73  16  2797  104*  49.07
# 8              JC Buttler (ENG)  2011-2023  109   100  21  2766  101*  35.01
# 9         Mohammad Hafeez (PAK)  2006-2021  119   108  13  2514   99*  26.46
# 10           KS Williamson (NZ)  2011-2022   87    85  11  2464    95  33.29
# ...

# %% [markdown]
# # Fetch the all tables from html file and stored in the local server

# %%
import pandas as pd
import requests

# %%
import pandas as pd
import requests

r = requests.get("https://stats.espncricinfo.com/ci/content/records/282827.html")
tables = pd.read_html(r.text)
print('Table found:',len(tables))
df1 = tables[0]
print('first table')
print(df1.head(15))
# Out:
# Table found: 1
# first table
#                     Player       Span  Mat  Inns  NO  Runs    HS    Ave    BF  \
# 0            V Kohli (IND)  2010-2022  115   107  31  4008  122*  52.73  2905
# 1          RG Sharma (IND)  2007-2022  148   140  17  3853   118  31.32  2767
# 2          MJ Guptill (NZ)  2009-2022  122   118   7  3531   105  31.81  2602
# 3         Babar Azam (PAK)  2016-2023  104    98  14  3485   122  41.48  2714
# 4        PR Stirling (IRE)  2009-2023  131   130  11  3408  115*  28.63  2509
# 5           AJ Finch (AUS)  2011-2022  103   103  12  3120   172  34.28  2189
# 6          DA Warner (AUS)  2009-2022   99    99  11  2894  100*  32.88  2048
# 7    Mohammad Rizwan (PAK)  2015-2023   85    73  16  2797  104*  49.07  2197
# 8         JC Buttler (ENG)  2011-2023  109   100  21  2766  101*  35.01  1912
# 9    Mohammad Hafeez (PAK)  2006-2021  119   108  13  2514   99*  26.46  2060
# 10      KS Williamson (NZ)  2011-2022   87    85  11  2464    95  33.29  2003
# ...

# %%
df1.to_html('write_html.html',index=False)

# %%
df1 = pd.read_html('write_html.html')

# %%
df1
# Out:
# [                Player       Span  Mat  Inns  NO  Runs    HS    Ave    BF  \
#  0        V Kohli (IND)  2010-2022  115   107  31  4008  122*  52.73  2905
#  1      RG Sharma (IND)  2007-2022  148   140  17  3853   118  31.32  2767
#  2      MJ Guptill (NZ)  2009-2022  122   118   7  3531   105  31.81  2602
#  3     Babar Azam (PAK)  2016-2023  104    98  14  3485   122  41.48  2714
#  4    PR Stirling (IRE)  2009-2023  131   130  11  3408  115*  28.63  2509
#  ..                 ...        ...  ...   ...  ..   ...   ...    ...   ...
#  145   IA Karim (KENYA)  2013-2022   44    40  11   888   71*  30.62   876
#  146      G Malla (NEP)  2014-2022   45    39   1   883   107  23.23   734
#  147      RP Burl (ZIM)  2018-2023   58    53  19   882   57*  25.94   749
#  148  K Motlhanka (BOT)  2019-2023   34    33   4   868   75*  29.93   763
#  149  AP Rajeevan (TAN)  2022-2023   39    36   6   861    70  28.70   731
#
#           SR 100  50   0   4s   6s
# ...

# %%
import webbrowser
import os

f = open('write_html.html','r')
f.read('write_html.html')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 5
#       2 import os
#       4 f = open('write_html.html','r')
# ----> 5 f.read('write_html.html')
#
# TypeError: argument should be integer or None, not 'str'

# %%
import pandas as pd
df = pd.read_html("https://www.cricbuzz.com/live-cricket-scorecard/78173/sl-vs-ban-super-fours-2nd-match-asia-cup-2023")
print(df)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_html("https://www.cricbuzz.com/live-cricket-scorecard/78173/sl-vs-ban-super-fours-2nd-match-asia-cup-2023")
#       3 print(df)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
import pandas as pd
df = pd.read_html("https://www.espncricinfo.com/series/ipl-2021-1249214/chennai-super-kings-vs-kolkata-knight-riders-final-1254117/full-scorecard")
df[0]
# Out:
#                                               BATTING  \
# 0                                     Ruturaj Gaikwad
# 1                                                 NaN
# 2                                      Faf du Plessis
# 3                                                 NaN
# 4                                       Robin Uthappa
# 5                                                 NaN
# 6                                           Moeen Ali
# 7                                              Extras
# 8                                               TOTAL
# 9   Did not bat: Ambati Rayudu, MS Dhoni (c)†, Rav...
# 10  Fall of wickets: 1-61 (Ruturaj Gaikwad, 8.1 ov...
#
#                                            Unnamed: 1  \
# 0                              c Shivam Mavi b Narine
# 1                                                 NaN
# 2                                c Iyer b Shivam Mavi
# 3                                                 NaN
# ...

# %%
import pandas as pd
df = pd.read_html("https://www.espncricinfo.com/series/ipl-2021-1249214/chennai-super-kings-vs-kolkata-knight-riders-final-1254117/full-scorecard")
df[1]
# Out:
#                                              BOWLING  \
# 0                                    Shakib Al Hasan
# 1                                        Shivam Mavi
# 2  19.6 to F du Plessis, he's holed out to long-o...
# 3                                    Lockie Ferguson
# 4                                 Varun Chakravarthy
# 5                                       Sunil Narine
# 6  8.1 to RD Gaikwad, dances down, and slices to ...
# 7                                     Venkatesh Iyer
#
#                                                    O  \
# 0                                                  3
# 1                                                  4
# 2  19.6 to F du Plessis, he's holed out to long-o...
# 3                                                  4
# 4                                                  4
# 5                                                  4
# 6  8.1 to RD Gaikwad, dances down, and slices to ...
# 7                                                  1
#
# ...

# %%
import pandas as pd
df = pd.read_html("https://www.espncricinfo.com/series/ipl-2021-1249214/chennai-super-kings-vs-kolkata-knight-riders-final-1254117/full-scorecard")
df[2]
# Out:
#                                               BATTING  \
# 0                                        Shubman Gill
# 1                                                 NaN
# 2                                      Venkatesh Iyer
# 3                                                 NaN
# 4                                         Nitish Rana
# 5                                                 NaN
# 6                                        Sunil Narine
# 7                                                 NaN
# 8                                     Eoin Morgan (c)
# 9                                                 NaN
# 10                                   Dinesh Karthik †
# 11                                                NaN
# 12                                    Shakib Al Hasan
# 13                                                NaN
# 14                                     Rahul Tripathi
# 15                                                NaN
# ...

# %%
import requests

from bs4 import BeautifulSoup

def getadata(url):
    r = requests.get(url)
    return r.text

htmldata = getadata("https://www.amazon.in/dp/B09MDCKB3K/ref=sspa_dk_detail_2?psc=1&pd_rd_i=B09MDCKB3K&pd_rd_w=UFAiV&content-id=amzn1.sym.b3dfef88-30a1-490c-be36-e990ef384667&pf_rd_p=b3dfef88-30a1-490c-be36-e990ef384667&pf_rd_r=BWWEH8XC3FV909ZG1ESA&pd_rd_wg=LXLQW&pd_rd_r=5780bee1-ab8f-423c-8a1b-94ecd4858972&s=kitchen&sp_csd=d2lkZ2V0TmFtZT1zcF9kZXRhaWw")

soup = BeautifulSoup(htmldata,"html.parser")

for item in soup.find_all('img'):
    print(item['src'])
# Out:
# https://images-na.ssl-images-amazon.com/captcha/xzqdsmvh/Captcha_mfshysyodr.jpg
# https://fls-eu.amazon.in/1/oc-csi/1/OP/requestId=KPNYRAEZAN8XVSFRJ8MS&js=0

# %%
import pandas as pd
df = pd.read_html("https://www.amazon.com/Ergonomic-Adjustable-Headrest-Reclining-High-Back/dp/B0C5LZFWL2/ref=sr_1_1_sspa?crid=ZYB37LVR56M8&keywords=chaires&qid=1694255702&sprefix=chaire%2Caps%2C703&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1")
df[12]
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_html("https://www.amazon.com/Ergonomic-Adjustable-Headrest-Reclining-High-Back/dp/B0C5LZFWL2/ref=sr_1_1_sspa?crid=ZYB37LVR56M8&keywords=chaires&qid=1694255702&sprefix=chaire%2Caps%2C703&sr=8-1-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1")
#       3 df[12]
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...
